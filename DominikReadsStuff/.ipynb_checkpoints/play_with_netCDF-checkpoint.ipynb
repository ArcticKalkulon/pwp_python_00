# %%
import numpy as np
import netCDF4 as nc

# %%
metData = nc.Dataset("../input_data/beaufort_met.nc", "r", format="NETCDF4")
print(metData)
# Out:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4_CLASSIC data model, file format HDF5):
#     Description: NetCDF verision of meteorological data storied in met.mat.
#     dimensions(sizes): t(217)
#     variables(dimensions): float64 time(t), float64 sw(t), float64 lw(t), float64 qlat(t), float64 qsens(t), float64 tx(t), float64 ty(t), float64 precip(t)
#     groups:

# %%
print(metData["time"])
# Out:
# <class 'netCDF4._netCDF4.Variable'>
# float64 time(t)
# unlimited dimensions:
# current shape = (217,)
# filling on, default _FillValue of 9.969209968386869e+36 used

# %%
print(metData["time"][:])
# Out:
# [ 1.     1.125  1.25   1.375  1.5    1.625  1.75   1.875  2.     2.125
#   2.25   2.375  2.5    2.625  2.75   2.875  3.     3.125  3.25   3.375
#   3.5    3.625  3.75   3.875  4.     4.125  4.25   4.375  4.5    4.625
#   4.75   4.875  5.     5.125  5.25   5.375  5.5    5.625  5.75   5.875
#   6.     6.125  6.25   6.375  6.5    6.625  6.75   6.875  7.     7.125
#   7.25   7.375  7.5    7.625  7.75   7.875  8.     8.125  8.25   8.375
#   8.5    8.625  8.75   8.875  9.     9.125  9.25   9.375  9.5    9.625
#   9.75   9.875 10.    10.125 10.25  10.375 10.5   10.625 10.75  10.875
#  11.    11.125 11.25  11.375 11.5   11.625 11.75  11.875 12.    12.125
#  12.25  12.375 12.5   12.625 12.75  12.875 13.    13.125 13.25  13.375
#  13.5   13.625 13.75  13.875 14.    14.125 14.25  14.375 14.5   14.625
#  14.75  14.875 15.    15.125 15.25  15.375 15.5   15.625 15.75  15.875
#  16.    16.125 16.25  16.375 16.5   16.625 16.75  16.875 17.    17.125
# ...

# %%
print(metData["sw"][:])
# Out:
# [172.24864197 173.73422581 175.27575023 176.87102772 178.51787078
#  180.21409188 181.95750354 183.74591822 185.57714844 187.71153589
#  190.26607229 193.02354513 195.76674188 198.27845003 200.34145706
#  201.73855045 202.2525177  202.14879501 201.87534428 201.48874152
#  201.04556274 200.60238397 200.21578121 199.94233048 199.83860779
#  200.15051854 200.98501685 202.19025175 203.61437232 205.10552759
#  206.51186664 207.68153851 208.46269226 208.9959699  209.51215022
#  209.99458741 210.42663568 210.79164924 211.07298229 211.25398903
#  211.31802368 211.25429177 211.08627129 210.84872508 210.57641602
#  210.30410695 210.06656075 209.89854026 209.83480835 209.95474839
#  210.28201553 210.76778027 211.36321314 212.01948463 212.68776527
#  213.31922556 213.86503601 214.33710523 214.7871211  215.22592303
#  215.66435046 216.11324279 216.58343947 217.0857799  217.63110352
#  218.26899304 219.01419926 219.82531369 220.66092783 221.4796332
# ...
